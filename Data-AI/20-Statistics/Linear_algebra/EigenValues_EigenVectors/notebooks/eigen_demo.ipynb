# %%
import numpy as np

A = np.array([
    [4,1],
    [2,3]
])

values, vectors = np.linalg.eig(A)

print(values)
print(vectors)
# Out:
# [5. 2.]
# [[ 0.70710678 -0.4472136 ]
#  [ 0.70710678  0.89442719]]
